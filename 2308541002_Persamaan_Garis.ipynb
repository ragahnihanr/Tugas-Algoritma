# %%
import numpy as np
import matplotlib.pyplot as plt

#Persamaan garis pertama melewati titik (a,b) dan titik (c,d)
#Titik (a,b)
a_02 = 10
b_02 = 5
#Titik (c,d)
c_02 = -10
d_02 = -5

#Mencari nilai gradien
m1_02 = d_02-b_02/c_02-a_02
print("Gradien garis pertama (m1) = {}".format(m1_02))

#Persamaan garis pertama y1 = m1*(x-a)+b
if -m1_02*a_02+b_02>0:
    print("Persamaan garis pertama (y1) ={}x+{} ".format(m1_02,-m1_02*a_02+b_02))
else:
    print("Persamaan garis pertama (y1) ={}x{} ".format(m1_02,-m1_02*a_02+b_02))

#Persamaan garis kedua melewati titik (e,f) dan titik (g,h)
#Berikut adalah titik (e,f)
e_02 = -10
f_02 = -5
#Berikut adalah titik (g,h)
g_02 = 10
h_02 = 5
#Mencari nilai gradien
m2_02 = h_02-f_02/g_02-e_02
print("Gradien garis kedua (m2) = {}".format(m2_02))
#Mencari persamaan garis kedua y2 = m2*(x-e)+f
if -m2_02*e_02+f_02>0:
    print("Persamaan garis kedua (y2) ={}x+{} ".format(m2_02,-m2_02*e_02+f_02))
else:
    print("Persamaan garis kedua (y2) ={}x{} ".format(m2_02,-m2_02*e_02+f_02))

#Membuktikan nilai gradien persamaan garis pertama dan kedua
if m1_02==m2_02:
    print("Karena memiliki nilai gardien yang sama, dan garis-garisnya berhimpit, maka memiliki tak hingga solusi")
else:
    #Menentukan titik potong kedua garis tp_x dan tp_y
    tp_x_02 = (m1_02*a_02-b_02-m2_02*e_02+f_02)/(m1_02-m2_02)
    tp_y_02 = m2_02*(tp_x_02-e_02)+f_02
    print("Titik potong kedua garis adalah ({},{})".format(tp_x_02,tp_y_02))
#Menentukan jangkauan nilai x    
x_02 = np.arange(tp_x_02-5,tp_x_02+5,0.1)
#Menentukan ukuran dan resolusi figure
plt.figure(figsize=(5, 5), dpi=150)
if -m1_02*a_02+b_02>0:
    plt.plot(x, m1_02*(x_02-a_02)+b_02, color='blue',label= 'y={}x+{}'.format(m1_02,-m1_02*a_02+b_02))
else:
    plt.plot(x, m1_02*(x_02-a_02)+b_02, color='blue',label= 'y={}x{}'.format(m1_02,-m1_02*a_02+b_02))
if -m2_02*e_02+f_02>0:
   plt.plot(x, m2_02*(x_02-e_02)+f_02, color='green',label = 'y={}x+{}'.format(m2_02,-m2_02*e_02+f_02))
else:
    plt.plot(x, m2_02*(x_02-e_02)+f_02, color='green',label = 'y={}x{}'.format(m2_02,-m2_02*e_02+f_02))    

plt.plot(tp_x_02,tp_y_02,color='red',marker='o', markersize=5) #Menampilkan titik potong pada kedua garis
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()
# Out:
# Gradien garis pertama (m1) = -14.5
# Persamaan garis pertama (y1) =-14.5x+150.0
# Gradien garis kedua (m2) = 15.5
# Persamaan garis kedua (y2) =15.5x+150.0
# Titik potong kedua garis adalah (-0.0,150.0)

# %%
import numpy as np
import matplotlib.pyplot as plt

#Persamaan garis pertama melewati titik (a,b) dan titik (c,d)
#Titik (a,b)
a_02 = 10
b_02 = 5
#Titik (c,d)
c_02 = -10
d_02 = -5

#Mencari nilai gradien
m1_02 = d_02-b_02/c_02-a_02
print("Gradien garis pertama (m1) = {}".format(m1_02))

#Persamaan garis pertama y1 = m1*(x-a)+b
if -m1_02*a_02+b_02>0:
    print("Persamaan garis pertama (y1) ={}x+{} ".format(m1_02,-m1_02*a_02+b_02))
else:
    print("Persamaan garis pertama (y1) ={}x{} ".format(m1_02,-m1_02*a_02+b_02))

#Persamaan garis kedua melewati titik (e,f) dan titik (g,h)
e_02 = a_02
f_02 = b_02
g_02 = c_02
h_02 = d_02
#Mencari nilai gradien
m2_02 = m1_02
print("Gradien garis kedua (m2) = {}".format(m2_02))
#Mencari persamaan garis kedua y2 = m2*(x-e)+f
if -m2_02*e_02+f_02>0:
    print("Persamaan garis kedua (y2) ={}x+{} ".format(m2_02,-m2_02*e_02+f_02))
else:
    print("Persamaan garis kedua (y2) ={}x{} ".format(m2_02,-m2_02*e_02+f_02))

#Membuktikan nilai gradien persamaan garis pertama dan kedua
if m1_02==m2_02:
    print("Karena memiliki nilai gardien yang sama, dan garis-garisnya berhimpit, maka memiliki tak hingga solusi")
else:
    #Menentukan titik potong kedua garis tp_x dan tp_y
    tp_x_02 = (m1_02*a_02-b_02-m2_02*e_02+f_02)/(m1_02-m2_02)
    tp_y_02 = m2_02*(tp_x_02-e_02)+f_02
    print("Titik potong kedua garis adalah ({},{})".format(tp_x_02,tp_y_02))
#Menentukan jangkauan nilai x    
x_02 = np.arange(tp_x_02-5,tp_x_02+5,0.1)
#Menentukan ukuran dan resolusi figure
plt.figure(figsize=(5, 5), dpi=150)
if -m1_02*a_02+b_02>0:
    plt.plot(x, m1_02*(x_02-a_02)+b_02, color='blue',label= 'y={}x+{}'.format(m1_02,-m1_02*a_02+b_02))
else:
    plt.plot(x, m1_02*(x_02-a_02)+b_02, color='blue',label= 'y={}x{}'.format(m1_02,-m1_02*a_02+b_02))
if -m2_02*e_02+f_02>0:
   plt.plot(x, m2_02*(x_02-e_02)+f_02, color='green',label = 'y={}x+{}'.format(m2_02,-m2_02*e_02+f_02))
else:
    plt.plot(x, m2_02*(x_02-e_02)+f_02, color='green',label = 'y={}x{}'.format(m2_02,-m2_02*e_02+f_02))    

plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()
# Out:
# Gradien garis pertama (m1) = -14.5
# Persamaan garis pertama (y1) =-14.5x+150.0
# Gradien garis kedua (m2) = -14.5
# Persamaan garis kedua (y2) =-14.5x+150.0
# Karena memiliki nilai gardien yang sama, dan garis-garisnya berhimpit, maka memiliki tak hingga solusi
