# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
nama = ['Ragah','Nihan','Razando']
print(nama)
# Out:
# ['Ragah', 'Nihan', 'Razando']

# %%
print(nama[2])
# Out:
# Razando

# %%
print(nama[-1])
# Out:
# Razando

# %%
nama[0] = 'Ni Made'
nama[1] = 'Rani'
print(nama)
# Out:
# ['Ni Made', 'Rani', 'Razando']

# %%
print(nama[0:2])
# Out:
# ['Ni Made', 'Rani']

# %%
SPTK = ['Dika','Wirya','Ragah','Ricardo','Yuda']
print(SPTK)
# Out:
# ['Dika', 'Wirya', 'Ragah', 'Ricardo', 'Yuda']

# %%
SPTK.append('Anggi')
print(SPTK)
# Out:
# ['Dika', 'Wirya', 'Ragah', 'Ricardo', 'Yuda', 'Anggi']

# %%
SPTK.insert(1,'Wira')
print(SPTK)
# Out:
# ['Dika', 'Wira', 'Wirya', 'Ragah', 'Ricardo', 'Yuda', 'Anggi']

# %%
SPTK.remove('Ricardo')
print(SPTK)
# Out:
# ['Dika', 'Wira', 'Wirya', 'Ragah', 'Yuda', 'Anggi']

# %%
print('Ricardo' in SPTK)
# Out:
# False

# %%
print('Ragah' in SPTK)
# Out:
# True

# %%
print(len(SPTK))
# Out:
# 6

# %%
merk = ['Xiaomi','Samsung','iPhone','POCO','Vivo']
for handphone in merk:
    print(handphone)
# Out:
# Xiaomi
# Samsung
# iPhone
# POCO
# Vivo

# %%
a = 0
while a < len(merk):
    print(merk[a])
    a+=1
# Out:
# Xiaomi
# Samsung
# iPhone
# POCO
# Vivo

# %%
a = 0
while a >= 0 and a < len(merk):
    print(merk[a])
    a-=1
# Out:
# Xiaomi

# %%
print("Pilih menu")
menu = ['1. Ayam Geprek','2. Ayam Goreng','3. Ayam Bakar']
for makan in menu:
    print(makan)
Q = int(input("Nomor berapa? (1/2/3)"))
if Q == 1:
    print('Ayam Geprek akan diantarkan kepada anda!')
elif Q == 2:
    print('Ayam Goreng akan diantarkan kepada anda!')
elif Q == 3:
    print('Ayam Bakar akan diantarkan kepada anda!')
else:
    print('Maaf, kami tidak menyediakan menu tersebut')
# Out:
# Pilih menu
# 1. Ayam Geprek
# 2. Ayam Goreng
# 3. Ayam Bakar
# Nomor berapa? (1/2/3) 3
# Ayam Bakar akan diantarkan kepada anda!

# %%
print("Pilih Avatar anda")
Avatar = ['1. Tanah','2. Api','3. Udara','4. Air','5. Es']
for user in Avatar:
    print(user)
Q = int(input("Avatar apakah anda?: (1/2/3/4/5)"))
if Q == 1:
    print("WAAAAHHH, Kamu pasti Amay !!!!!")
elif Q == 2:
    print("WAAAAHHH, Kamu pasti Ratih Isaka !!!!!")
elif Q == 3:
    print("WAAAAHHH, Kamu pasti Kharina !!!!!")
elif Q == 4:
    print("WAAAAHHH, Kamu pasti Dian !!!!!")
elif Q == 5:
    print("Kamu memilih Es, sudah pasti kamu adalah pembuat program ini yaitu Ragah seorang Avatar langka")
else:
    print("Tidak ada Avatar tersebut")
# Out:
# Pilih Avatar anda
# 1. Tanah
# 2. Api
# 3. Udara
# 4. Air
# 5. Es
# Avatar apakah anda?: (1/2/3/4/5) 3
# WAAAAHHH, Kamu pasti Kharina !!!!!
